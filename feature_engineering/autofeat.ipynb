# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import featuretools as ft
import hashlib

from dotenv import dotenv_values

# %%
config = dotenv_values('../.env')

# %%
train = pd.read_parquet(config["INT_TRAIN_PARQUET"])

# %%
train.head()
# Out:
#                                          customer_ID         S_2       P_2  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09  0.938469
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07  0.936665
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28  0.954180
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13  0.960384
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16  0.947248
#
#    D_39       B_1       B_2       R_1       S_3  D_41       B_3  ...  D_136  \
# 0     0  0.008724  1.006838  0.009228  0.124035   0.0  0.004709  ...     -1
# 1     0  0.004923  1.000653  0.006151  0.126750   0.0  0.002714  ...     -1
# 2     3  0.021655  1.009672  0.006815  0.123977   0.0  0.009423  ...     -1
# 3     0  0.013683  1.002700  0.001373  0.117169   0.0  0.005531  ...     -1
# 4     0  0.015193  1.000727  0.007605  0.117325   0.0  0.009312  ...     -1
#
# ...

# %%
# test = pd.read_parquet(config["INT_TEST_PARQUET"])

# %%
# test.head()

# %% [markdown]
# # Quickstart

# %%
# Create unique index
idx = [int(hashlib.md5(s.encode()).hexdigest(),16) for s in train["customer_ID"]]
idx
# Out:
# [93172428035851364487680624147424147114,
#  93172428035851364487680624147424147114,
#  93172428035851364487680624147424147114,
#  93172428035851364487680624147424147114,
#  93172428035851364487680624147424147114,
#  93172428035851364487680624147424147114,
#  93172428035851364487680624147424147114,
#  93172428035851364487680624147424147114,
#  93172428035851364487680624147424147114,
#  93172428035851364487680624147424147114,
#  93172428035851364487680624147424147114,
#  93172428035851364487680624147424147114,
#  93172428035851364487680624147424147114,
#  95969726175517658061683525588645360597,
#  95969726175517658061683525588645360597,
#  95969726175517658061683525588645360597,
#  95969726175517658061683525588645360597,
#  95969726175517658061683525588645360597,
#  95969726175517658061683525588645360597,
#  95969726175517658061683525588645360597,
#  95969726175517658061683525588645360597,
#  95969726175517658061683525588645360597,
#  95969726175517658061683525588645360597,
# ...

# %%
train.set_index(idx)

# %%
dataframes = {
    "train": (train, "customer_ID", "S_2"),
#     "test": (test, "customer_ID", "S_2")
}

# %%
feature_matrix_train, features_defs = ft.dfs(
    dataframes=dataframes,
    target_dataframe_name="train"
)

# %%
feature_matrix_train
