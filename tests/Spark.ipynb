# %% [markdown]
# # Import Libraries

# %%
import pyspark
from pyspark.sql import SparkSession
from dotenv import dotenv_values

# %% [markdown]
# # Environment Variable Config

# %%
config = dotenv_values('../.env')

# %% [markdown]
# # Step 1: Create Spark Session

# %%
spark=SparkSession.builder.appName('Practice').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-EI40B8Q:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark_df=spark.read.csv(config['TRAIN_PATH'])

# %%
spark_df
# Out:
# DataFrame[_c0: string, _c1: string, _c2: string, _c3: string, _c4: string, _c5: string, _c6: string, _c7: string, _c8: string, _c9: string, _c10: string, _c11: string, _c12: string, _c13: string, _c14: string, _c15: string, _c16: string, _c17: string, _c18: string, _c19: string, _c20: string, _c21: string, _c22: string, _c23: string, _c24: string, _c25: string, _c26: string, _c27: string, _c28: string, _c29: string, _c30: string, _c31: string, _c32: string, _c33: string, _c34: string, _c35: string, _c36: string, _c37: string, _c38: string, _c39: string, _c40: string, _c41: string, _c42: string, _c43: string, _c44: string, _c45: string, _c46: string, _c47: string, _c48: string, _c49: string, _c50: string, _c51: string, _c52: string, _c53: string, _c54: string, _c55: string, _c56: string, _c57: string, _c58: string, _c59: string, _c60: string, _c61: string, _c62: string, _c63: string, _c64: string, _c65: string, _c66: string, _c67: string, _c68: string, _c69: string, _c70: string, _c71
# ...

# %%
spark_df.show()
# Out:
# +--------------------+----------+------------------+------------------+------------------+------------------+--------------------+------------------+--------------------+--------------------+----+----+--------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+----+------------------+------------------+--------------------+------------------+------------------+--------------------+--------------------+------------------+------------------+------------------+----+------------------+--------------------+--------------------+------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+--------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+----+----+----------------
# ...

# %%
spark_df=spark.read.option('header', 'true').csv(config['TRAIN_PATH'])
spark_df
# Out:
# DataFrame[customer_ID: string, S_2: string, P_2: string, D_39: string, B_1: string, B_2: string, R_1: string, S_3: string, D_41: string, B_3: string, D_42: string, D_43: string, D_44: string, B_4: string, D_45: string, B_5: string, R_2: string, D_46: string, D_47: string, D_48: string, D_49: string, B_6: string, B_7: string, B_8: string, D_50: string, D_51: string, B_9: string, R_3: string, D_52: string, P_3: string, B_10: string, D_53: string, S_5: string, B_11: string, S_6: string, D_54: string, R_4: string, S_7: string, B_12: string, S_8: string, D_55: string, D_56: string, B_13: string, R_5: string, D_58: string, S_9: string, B_14: string, D_59: string, D_60: string, D_61: string, B_15: string, S_11: string, D_62: string, D_63: string, D_64: string, D_65: string, B_16: string, B_17: string, B_18: string, B_19: string, D_66: string, B_20: string, D_68: string, S_12: string, R_6: string, S_13: string, B_21: string, D_69: string, B_22: string, D_70: string, D_71: string, D_72: strin
# ...

# %%
type(spark_df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
spark_df.head()
# Out:
# Row(customer_ID='0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fbac11a8ed792feb62a', S_2='2017-03-09', P_2='0.9384687191272548', D_39='0.0017333390041739', B_1='0.0087244509498605', B_2='1.0068382339663076', R_1='0.0092277222786689', S_3='0.1240351558143743', D_41='0.0087711319938824', B_3='0.0047092406313857', D_42=None, D_43=None, D_44='0.000630134804911503', B_4='0.0809863324662527', D_45='0.708906305121159', B_5='0.1706002293387026', R_2='0.0062040314303209', D_46='0.3585865793715965', D_47='0.525351040810055', D_48='0.255736073902975', D_49=None, B_6='0.0639022133803909', B_7='0.0594157330614109', B_8='0.006465576798311', D_50='0.1486979558199995', D_51='1.3358557940752642', B_9='0.0082067391252636', R_3='0.0014225021561254', D_52='0.2073338786110817', P_3='0.7364627260945562', B_10='0.0962188066642168', D_53=None, S_5='0.0233811220509184', B_11='0.0027680616648439', S_6='0.0083216461012018', D_54='1.0015189798143298', R_4='0.0082984353659013', S_7='0.1613448213392926', B_12='0.1
# ...

# %%
spark_df.printSchema()
# Out:
# root
#  |-- customer_ID: string (nullable = true)
#  |-- S_2: string (nullable = true)
#  |-- P_2: string (nullable = true)
#  |-- D_39: string (nullable = true)
#  |-- B_1: string (nullable = true)
#  |-- B_2: string (nullable = true)
#  |-- R_1: string (nullable = true)
#  |-- S_3: string (nullable = true)
#  |-- D_41: string (nullable = true)
#  |-- B_3: string (nullable = true)
#  |-- D_42: string (nullable = true)
#  |-- D_43: string (nullable = true)
#  |-- D_44: string (nullable = true)
#  |-- B_4: string (nullable = true)
#  |-- D_45: string (nullable = true)
#  |-- B_5: string (nullable = true)
#  |-- R_2: string (nullable = true)
#  |-- D_46: string (nullable = true)
#  |-- D_47: string (nullable = true)
#  |-- D_48: string (nullable = true)
#  |-- D_49: string (nullable = true)
#  |-- B_6: string (nullable = true)
#  |-- B_7: string (nullable = true)
#  |-- B_8: string (nullable = true)
#  |-- D_50: string (nullable = true)
#  |-- D_51: string (nullable = true)
# ...

# %% [markdown]
# # Pyspark Dataframe Part 1
# - PySpark Dataframe
# - Reading the dataset
# - Checking the datatypes of the column(Schema)
# - Selecting Columns and indexing
# - Check describe option similar to pandas
# - Adding columns
# - Dropping columns

# %%
### Check schema
spark_df.printSchema()
# Out:
# root
#  |-- customer_ID: string (nullable = true)
#  |-- S_2: string (nullable = true)
#  |-- P_2: string (nullable = true)
#  |-- D_39: string (nullable = true)
#  |-- B_1: string (nullable = true)
#  |-- B_2: string (nullable = true)
#  |-- R_1: string (nullable = true)
#  |-- S_3: string (nullable = true)
#  |-- D_41: string (nullable = true)
#  |-- B_3: string (nullable = true)
#  |-- D_42: string (nullable = true)
#  |-- D_43: string (nullable = true)
#  |-- D_44: string (nullable = true)
#  |-- B_4: string (nullable = true)
#  |-- D_45: string (nullable = true)
#  |-- B_5: string (nullable = true)
#  |-- R_2: string (nullable = true)
#  |-- D_46: string (nullable = true)
#  |-- D_47: string (nullable = true)
#  |-- D_48: string (nullable = true)
#  |-- D_49: string (nullable = true)
#  |-- B_6: string (nullable = true)
#  |-- B_7: string (nullable = true)
#  |-- B_8: string (nullable = true)
#  |-- D_50: string (nullable = true)
#  |-- D_51: string (nullable = true)
# ...

# %%
'''
Since it defaults to representing everything as strings
we use the inferSchema parameter in order to store the
numerical data properly
''' 
spark_df = spark.read.csv(config["TRAIN_PATH"], header=True, inferSchema=True)

# %%
spark_df.printSchema()
# Out:
# root
#  |-- customer_ID: string (nullable = true)
#  |-- S_2: timestamp (nullable = true)
#  |-- P_2: double (nullable = true)
#  |-- D_39: double (nullable = true)
#  |-- B_1: double (nullable = true)
#  |-- B_2: double (nullable = true)
#  |-- R_1: double (nullable = true)
#  |-- S_3: double (nullable = true)
#  |-- D_41: double (nullable = true)
#  |-- B_3: double (nullable = true)
#  |-- D_42: double (nullable = true)
#  |-- D_43: double (nullable = true)
#  |-- D_44: double (nullable = true)
#  |-- B_4: double (nullable = true)
#  |-- D_45: double (nullable = true)
#  |-- B_5: double (nullable = true)
#  |-- R_2: double (nullable = true)
#  |-- D_46: double (nullable = true)
#  |-- D_47: double (nullable = true)
#  |-- D_48: double (nullable = true)
#  |-- D_49: double (nullable = true)
#  |-- B_6: double (nullable = true)
#  |-- B_7: double (nullable = true)
#  |-- B_8: double (nullable = true)
#  |-- D_50: double (nullable = true)
#  |-- D_51: double (nullable = true)
# ...

# %%
spark_df.columns
# Out:
# ['customer_ID',
#  'S_2',
#  'P_2',
#  'D_39',
#  'B_1',
#  'B_2',
#  'R_1',
#  'S_3',
#  'D_41',
#  'B_3',
#  'D_42',
#  'D_43',
#  'D_44',
#  'B_4',
#  'D_45',
#  'B_5',
#  'R_2',
#  'D_46',
#  'D_47',
#  'D_48',
#  'D_49',
#  'B_6',
#  'B_7',
#  'B_8',
#  'D_50',
#  'D_51',
#  'B_9',
#  'R_3',
#  'D_52',
#  'P_3',
#  'B_10',
#  'D_53',
#  'S_5',
#  'B_11',
#  'S_6',
#  'D_54',
#  'R_4',
#  'S_7',
#  'B_12',
#  'S_8',
#  'D_55',
#  'D_56',
#  'B_13',
#  'R_5',
#  'D_58',
#  'S_9',
#  'B_14',
#  'D_59',
#  'D_60',
#  'D_61',
#  'B_15',
#  'S_11',
#  'D_62',
#  'D_63',
#  'D_64',
#  'D_65',
#  'B_16',
#  'B_17',
#  'B_18',
#  'B_19',
#  'D_66',
#  'B_20',
#  'D_68',
#  'S_12',
#  'R_6',
#  'S_13',
#  'B_21',
#  'D_69',
#  'B_22',
#  'D_70',
#  'D_71',
#  'D_72',
#  'S_15',
#  'B_23',
#  'D_73',
#  'P_4',
#  'D_74',
#  'D_75',
#  'D_76',
#  'B_24',
#  'R_7',
#  'D_77',
#  'B_25',
#  'B_26',
#  'D_78',
#  'D_79',
#  'R_8',
#  'R_9',
#  'S_16',
#  'D_80',
#  'R_10',
#  'R_11',
# ...

# %%
spark_df.select('customer_ID').show()
# Out:
# +--------------------+
# |         customer_ID|
# +--------------------+
# |0000099d6bd597052...|
# |0000099d6bd597052...|
# |0000099d6bd597052...|
# |0000099d6bd597052...|
# |0000099d6bd597052...|
# |0000099d6bd597052...|
# |0000099d6bd597052...|
# |0000099d6bd597052...|
# |0000099d6bd597052...|
# |0000099d6bd597052...|
# |0000099d6bd597052...|
# |0000099d6bd597052...|
# |0000099d6bd597052...|
# |00000fd6641609c6e...|
# |00000fd6641609c6e...|
# |00000fd6641609c6e...|
# |00000fd6641609c6e...|
# |00000fd6641609c6e...|
# |00000fd6641609c6e...|
# |00000fd6641609c6e...|
# +--------------------+
# only showing top 20 rows

# %%
spark_df.select(['customer_ID', 'S_2', 'S_3']).show()
# Out:
# +--------------------+-------------------+------------------+
# |         customer_ID|                S_2|               S_3|
# +--------------------+-------------------+------------------+
# |0000099d6bd597052...|2017-03-09 00:00:00|0.1240351558143743|
# |0000099d6bd597052...|2017-04-07 00:00:00| 0.126749984407325|
# |0000099d6bd597052...|2017-05-28 00:00:00| 0.123976686890962|
# |0000099d6bd597052...|2017-06-13 00:00:00|0.1171692268847632|
# |0000099d6bd597052...|2017-07-16 00:00:00|0.1173247782682111|
# |0000099d6bd597052...|2017-08-04 00:00:00|0.1109455761415355|
# |0000099d6bd597052...|2017-09-18 00:00:00|0.1033294124109542|
# |0000099d6bd597052...|2017-10-08 00:00:00|0.1081150019235464|
# |0000099d6bd597052...|2017-11-20 00:00:00| 0.102792263129184|
# |0000099d6bd597052...|2017-12-04 00:00:00|0.1004697554252383|
# |0000099d6bd597052...|2018-01-11 00:00:00|0.0988818933861745|
# |0000099d6bd597052...|2018-02-21 00:00:00|0.1029847581731688|
# ...

# %%
spark_df.dtypes
# Out:
# [('customer_ID', 'string'),
#  ('S_2', 'timestamp'),
#  ('P_2', 'double'),
#  ('D_39', 'double'),
#  ('B_1', 'double'),
#  ('B_2', 'double'),
#  ('R_1', 'double'),
#  ('S_3', 'double'),
#  ('D_41', 'double'),
#  ('B_3', 'double'),
#  ('D_42', 'double'),
#  ('D_43', 'double'),
#  ('D_44', 'double'),
#  ('B_4', 'double'),
#  ('D_45', 'double'),
#  ('B_5', 'double'),
#  ('R_2', 'double'),
#  ('D_46', 'double'),
#  ('D_47', 'double'),
#  ('D_48', 'double'),
#  ('D_49', 'double'),
#  ('B_6', 'double'),
#  ('B_7', 'double'),
#  ('B_8', 'double'),
#  ('D_50', 'double'),
#  ('D_51', 'double'),
#  ('B_9', 'double'),
#  ('R_3', 'double'),
#  ('D_52', 'double'),
#  ('P_3', 'double'),
#  ('B_10', 'double'),
#  ('D_53', 'double'),
#  ('S_5', 'double'),
#  ('B_11', 'double'),
#  ('S_6', 'double'),
#  ('D_54', 'double'),
#  ('R_4', 'double'),
#  ('S_7', 'double'),
#  ('B_12', 'double'),
#  ('S_8', 'double'),
#  ('D_55', 'double'),
#  ('D_56', 'double'),
#  ('B_13', 'double'),
#  ('R_5', 'double'),
# ...

# %%
spark_df.describe().show()
# Out:
# +-------+--------------------+-------------------+--------------------+-------------------+--------------------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+-------------------+-------------------+--------------------+-------------------+-------------------+--------------------+-------------------+--------------------+--------------------+--------------------+-------------------+-------------------+-------------------+--------------------+--------------------+--------------------+--------------------+-------------------+--------------------+-------------------+--------------------+--------------------+--------------------+-------------------+--------------------+--------------------+-------------------+--------------------+-------------------+-------------------+--------------------
# ...

# %%
### Adding Columns
# spark_df.withColumn('Test Column', values)

# %%
### Dropping Columns
# spark_df.drop(column_name[s])

# %% [markdown]
# # Handling Missing Values
# - Dropping columns
# - Dropping rows
# - Various parameter in dropping functionalities
# - Handling missing values by mean, median, and mode

# %%
'''
Where ever there's a null value the entire row gets deleted

how: 
- 'any': drop a row if it contains any null
- 'all': drop a row if all values are null

thresh: drops rows that have less than n non-null values

subset: list of column names to consider
'''
# spark_df.na.drop()

# %%
'''
Fill the null values in the dataframe

value: Replaces the null value with the value provided

subset: list of column names to consider
'''
# spark_df.na.fill()
# Out:
# '\nFill the null values in the dataframe\n\nvalue: Replaces the null value with the value provided\n\nsubset: list of column names to consider\n'

# %%
'''
Imputer

Fills in any null values according to a specific strategy

Strategies:
- mean
- median
- mode
'''
from pyspark.ml.feature import Imputer

'''
imputer = Imputer(
    inputCols = [cols],
    outputCols = [out_cols]
    ).setStrategy("mean")
'''

# %% [markdown]
# # Pyspark Dataframe Part 2: Filter Operations
# - Filter operations
# - &,|,==
# - ~
